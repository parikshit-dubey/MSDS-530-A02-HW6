# %%
# Import libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Read the data

df = pd.read_csv("HW6_Iris_Dataset.csv")

# %%
# Print the dataframe

print(df)
# Out:
#     sepalWidth  petalWidth sampleNum      irisSpecies
# 0          3.5         0.2      id_1      Iris-setosa
# 1          3.0         0.2      id_2      Iris-setosa
# 2          3.6         0.2      id_5      Iris-setosa
# 3          3.9         0.4      id_6      Iris-setosa
# 4          3.4         0.3      id_7      Iris-setosa
# ..         ...         ...       ...              ...
# 95         3.4         1.6     id_86  Iris-versicolor
# 96         2.3         1.3     id_88  Iris-versicolor
# 97         3.0         1.4     id_92  Iris-versicolor
# 98         2.7         1.3     id_95  Iris-versicolor
# 99         2.8         1.3    id_100  Iris-versicolor
#
# [100 rows x 4 columns]

# %%
# Convert irisSpecies to numeric values

df['irisSpecies'] = df['irisSpecies'].map({'Iris-setosa': 0, 'Iris-versicolor': 1})

# Features and Target variable

X = df[['sepalWidth', 'petalWidth']]
y = df['irisSpecies']

# %%
# Print features and Target variables

print(X)
print(y)

# Feature scaling
scaler = StandardScaler()
X = scaler.fit_transform(X)
# Out:
#     sepalWidth  petalWidth
# 0          3.5         0.2
# 1          3.0         0.2
# 2          3.6         0.2
# 3          3.9         0.4
# 4          3.4         0.3
# ..         ...         ...
# 95         3.4         1.6
# 96         2.3         1.3
# 97         3.0         1.4
# 98         2.7         1.3
# 99         2.8         1.3
#
# [100 rows x 2 columns]
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: irisSpecies, Length: 100, dtype: int64

# %%
# Split training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create the ANN model
model = Sequential()

# %%
# Adding layers

# Input and first layer
model.add(Dense(units=64, activation='relu', input_shape=(2,)))  

# First hidden layer
model.add(Dense(units=32, activation='tanh')) 

# Second hidden layer
model.add(Dense(units=32, activation='relu'))

# Output layer
model.add(Dense(units=1, activation='sigmoid'))

# Compiling the ANN
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the ANN
model.fit(X_train, y_train, batch_size=5, epochs=100)  

# evaluate the model
x , score = model.evaluate(X_test, y_test)
print('Accuracy of the model: %.3f' % (score*100))
# Out:
# Epoch 1/100
# 15/15 [==============================] - 0s 640us/step - loss: 0.6177 - accuracy: 0.9600
# Epoch 2/100
# 15/15 [==============================] - 0s 573us/step - loss: 0.5058 - accuracy: 1.0000
# Epoch 3/100
# 15/15 [==============================] - 0s 632us/step - loss: 0.3995 - accuracy: 1.0000
# Epoch 4/100
# 15/15 [==============================] - 0s 620us/step - loss: 0.3051 - accuracy: 1.0000
# Epoch 5/100
# 15/15 [==============================] - 0s 632us/step - loss: 0.2304 - accuracy: 1.0000
# Epoch 6/100
# 15/15 [==============================] - 0s 645us/step - loss: 0.1672 - accuracy: 1.0000
# Epoch 7/100
# 15/15 [==============================] - 0s 638us/step - loss: 0.1107 - accuracy: 1.0000
# Epoch 8/100
# 15/15 [==============================] - 0s 690us/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 9/100
# 15/15 [==============================] - 0s 627us/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 10/100
# 15/15 [==============================] - 0s 716us/step - loss: 0.0216 - accuracy: 1.0000
# Epoch